# %%
# %load_ext sql
# Out:
# The 'toml' package isn't installed. To load settings from pyproject.toml or ~/.jupysql/config, install with: pip install toml

# %%
# %sql postgresql://postgres:admin@postgres-db:5432/dop
# Out:
# Connecting to 'postgresql://postgres:***@postgres-db:5432/dop'

# %%
# %config SqlMagic.displaylimit = 10

# %%
# %%sql
# -- estabalecimentos por bairro
# SELECT
#     b.nome,
#     b.codigo,
#     b.id_bac,
#     COUNT(a.id) AS quantidade_estabelecimentos
# FROM silver.bairro_oficial b
# JOIN silver.atividade_economica a ON ST_Within(a.geometria, b.geometria)
# GROUP BY b.id, b.nome, b.codigo, b.id_bac
# ORDER BY quantidade_estabelecimentos DESC
# LIMIT 10
# Out:
# Running query in 'postgresql://postgres:***@postgres-db:5432/dop'
# 10 rows affected.
# +---------------+--------+--------+-----------------------------+
# |      nome     | codigo | id_bac | quantidade_estabelecimentos |
# +---------------+--------+--------+-----------------------------+
# |     sétima    |   7    |  185   |            13794            |
# |    terceira   |   3    |  178   |            12067            |
# |    primeira   |   1    |  181   |            10768            |
# | carlos prates |  104   |  159   |             9240            |
# |    estoril    |  170   |  210   |             9039            |
# |  afonso pena  |  120   |  202   |             8547            |
# |  dos buritis  |  171   |  212   |             7572            |
# |   do castelo  |  295   |   80   |             7361            |
# |    segunda    |  102   |  194   |             7321            |
# |     sexta     |  106   |  302   |             6577            |
# +---------------+--------+--------+-----------------------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# SELECT
#     b.nome,
#     b.codigo,
#     COUNT(a.id) AS quantidade_meis
# FROM silver.bairro_oficial b
# JOIN silver.atividade_economica a ON ST_Within(a.geometria, b.geometria)
# WHERE a.ind_mei = TRUE
# GROUP BY b.id, b.nome, b.codigo
# ORDER BY quantidade_meis DESC
# LIMIT 10
# Out:
# Running query in 'postgresql://postgres:***@postgres-db:5432/dop'
# 10 rows affected.
# +--------------------------+--------+-----------------+
# |           nome           | codigo | quantidade_meis |
# +--------------------------+--------+-----------------+
# |          jatobá          |  618   |       4900      |
# |           tupi           |  967   |       4165      |
# | antônio ribeiro de abreu |  919   |       3765      |
# |        vera cruz         |  453   |       3654      |
# |        boa vista         |  830   |       3230      |
# |       mantiqueira        |  969   |       3178      |
# |      carlos prates       |  104   |       3112      |
# |         lindéia          |  639   |       3095      |
# |         vitória          |  776   |       2990      |
# |         diamante         |  629   |       2975      |
# +--------------------------+--------+-----------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# -- Quais linhas de ônibus passam por áreas mais comerciais
# SELECT
#     po.cod_linha,
#     po.nome_linha,
#     COUNT(DISTINCT e.id) AS empresas_ao_longo_da_linha,
#     COUNT(DISTINCT po.id) AS pontos_na_linha,
#     ROUND(COUNT(DISTINCT e.id)::NUMERIC / COUNT(DISTINCT po.id), 2) AS empresas_por_ponto
# FROM silver.ponto_onibus po
# LEFT JOIN silver.atividade_economica e ON ST_DWithin(e.geometria, po.geometria, 100)
# GROUP BY po.cod_linha, po.nome_linha
# ORDER BY empresas_ao_longo_da_linha DESC
# Out:
# Running query in 'postgresql://postgres:***@postgres-db:5432/dop'
# 334 rows affected.
# +-----------+--------------------------------------+----------------------------+-----------------+--------------------+
# | cod_linha |              nome_linha              | empresas_ao_longo_da_linha | pontos_na_linha | empresas_por_ponto |
# +-----------+--------------------------------------+----------------------------+-----------------+--------------------+
# |    4107   |          alto caicara-serra          |           26484            |       577       |       45.90        |
# |    8207   |     maria goretti-estrela dalva      |           25810            |       298       |       86.61        |
# |    8102   |           uniao-carmo sion           |           24536            |       585       |       41.94        |
# |    4102   |           aparecida-serra            |           24509            |       335       |       73.16        |
# |    8205   |      maria goretti-nova granada      |           23935            |       1427      |       16.77        |
# |    2102   |          gameleira - serra           |           23559            |       387       |       60.88        |
# |    9412   |    conj.taquaril-padre eustaquio     |           23432            |       746       |       31.41        |
# |    8108   | cidade nova-savassi via rua da bahia |           23043            |       271       |       85.03        |
# |   4801a   |    jardim filadelfia-boa vista a     |           22603            |       618       |       36.57        |
# |    8106   | santa cruz-bh shopping via belvedere |           22097            |       590       |       37.45        |
# +-----------+--------------------------------------+----------------------------+-----------------+--------------------+
# Truncated to displaylimit of 10.
